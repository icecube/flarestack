# %% [markdown]
# # Setup
# The first step when using flarestack is to define a path for data to be saved to. This directory is desgined to be 'disposable', so can be regenerated if necessary. It is a central place for saving both plots, analysis results and values that only need to be calculated once, such as inputs for splines. Once you define the parent directory, a subdirectory is automatically created. *This only needs to be done once, so you can skip this step on future occasions!*

# %%
from pathlib import Path
home = str(Path.home())
from flarestack.precompute import run_precompute, set_scratch_directory
set_scratch_directory(home)
# Out:
# Setting scratch path to /Users/avocado/

# %%
from flarestack.data.icecube.public.all_sky_point_source.all_sky_3_year import ps_3_year
run_precompute(ps_3_year, ask=False)
# Out:
# Loading datasets from /lustre/fs22/group/icecube/data_mirror/ (DESY)
#
#
#
# ********************************************************************
# *                                                                  *
# *                Initialising setup for FlareStack                 *
# *                                                                  *
# ********************************************************************
#
#
#   Initialising directory for data storage. This could be a scratch
#                    space or local directory.
#
#
# The following parent directory has been found in config.py:
#
# 	 /Users/avocado/
#
# A new data storage directory will be created at:
#
# 	 /Users/avocado/flarestack__data/
#
# Found Directory: /Users/avocado/flarestack__data/
# Found Directory: /Users/avocado/flarestack__data/input/
# Found Directory: /Users/avocado/flarestack__data/storage/
# Found Directory: /Users/avocado/flarestack__data/output/
# Found Directory: /Users/avocado/flarestack__data/cluster/
# Found Directory: /Users/avocado/flarestack__data/input/pull_corrections/
# Found Directory: /Users/avocado/flarestack__data/cluster/logs/
# Found Directory: /Users/avocado/flarestack__data/input/catalogues/
# Found Directory: /Users/avocado/flarestack__data/input/acceptance_functions/
# Found Directory: /Users/avocado/flarestack__data/storage/pickles/
# Found Directory: /Users/avocado/flarestack__data/output/plots/
# Found Directory: /Users/avocado/flarestack__data/input/SoB_splines/
# Found Directory: /Users/avocado/flarestack__data/input/analysis/
# Found Directory: /Users/avocado/flarestack__data/output/plots/illustrations/
# Found Directory: /Users/avocado/flarestack__data/input/catalogues/transients/
# Found Directory: /Users/avocado/flarestack__data/input/bkg_splines/
# Found Directory: /Users/avocado/flarestack__data/output/dataset_plots/
# Found Directory: /Users/avocado/flarestack__data/output/limits/
# Found Directory: /Users/avocado/flarestack__data/input/pull_corrections/pulls/
# Found Directory: /Users/avocado/flarestack__data/input/pull_corrections/floors/
# Found Directory: /Users/avocado/flarestack__data/storage/cache/
# Found Directory: /Users/avocado/flarestack__data/storage/cache/catalogue_cache/
# Found Directory: /Users/avocado/flarestack__data/input/public_datasets/
# Found Directory: /Users/avocado/flarestack__data/input/energy_proxy_weighting/
# Found Directory: /Users/avocado/flarestack__data/output/dataset_plots/effective_area_plots/
# Found Directory: /Users/avocado/flarestack__data/input/median_angular_resolution/
# Found Directory: /Users/avocado/flarestack__data/output/dataset_plots/angular_resolution_plots/
# Found Directory: /Users/avocado/flarestack__data/output/dataset_plots/energy_proxy_map/
#
#
# ********************************************************************
# *                                                                  *
# *                    Generating Cluster Scripts                    *
# *                                                                  *
# ********************************************************************
#
#
# Creating file at /Users/avocado/flarestack/flarestack/cluster/SubmitDESY.sh
# Bash file created:
#
# #!/bin/zsh
# ##
# ##(otherwise the default shell would be used)
# #$ -S /bin/zsh
# ##
# ##(the running time for this job)
# #$ -l h_cpu=23:59:00
# #$ -l h_rss=6.0G
# ##
# ##
# ##(send mail on job's abort)
# #$ -m a
# ##
# ##(stderr and stdout are merged together to stdout)
# #$ -j y
# ##
# ## name of the job
# ## -N Flarestack script avocado
# ##
# ##(redirect output to:)
# #$ -o /dev/null
# ##
# sleep $(( ( RANDOM % 60 )  + 1 ))
# exec > "$TMPDIR"/${JOB_ID}_stdout.txt 2>"$TMPDIR"/${JOB_ID}_stderr.txt
# eval $(/cvmfs/icecube.opensciencegrid.org/py3-v4/setup.sh)
# export PYTHONPATH=/Users/avocado/flarestack/
# python /Users/avocado/flarestack/flarestack/core/multiprocess_wrapper.py -f $1 -n $2
# cp $TMPDIR/${JOB_ID}_stdout.txt /Users/avocado/flarestack__data/cluster/logs/
# cp $TMPDIR/${JOB_ID}_stderr.txt /Users/avocado/flarestack__data/cluster/logs/
#
#
#
# ********************************************************************
# *                                                                  *
# *                 Initialising catalogue creation                  *
# *                                                                  *
# ********************************************************************
#
#
# Making single-source catalogues for the following sin(declinations):
# [ 1.    0.95  0.9   0.85  0.8   0.75  0.7   0.65  0.6   0.55  0.5   0.45
#   0.4   0.35  0.3   0.25  0.2   0.15  0.1   0.05  0.   -0.05 -0.1  -0.15
#  -0.2  -0.25 -0.3  -0.35 -0.4  -0.45 -0.5  -0.55 -0.6  -0.65 -0.7  -0.75
#  -0.8  -0.85 -0.9  -0.95 -1.  ]
#
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_1.00.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.95.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.90.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.85.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.80.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.75.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.70.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.65.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.60.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.55.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.50.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.45.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.40.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.35.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.30.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.25.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.20.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.15.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.10.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.05.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_0.00.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.05.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.10.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.15.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.20.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.25.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.30.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.35.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.40.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.45.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.50.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.55.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.60.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.65.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.70.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.75.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.80.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.85.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.90.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-0.95.npy
# Saving to /Users/avocado/flarestack__data/input/catalogues/single_source/sindec_-1.00.npy
#
#
# Single Source catalogues created!
#
# ********************************************************************
# *                                                                  *
# *                     Checking data directories                    *
# *                                                                  *
# ********************************************************************
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/IC79-2010.npy
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/pseudo_mc/IC79-2010.npy
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/IC86-2011.npy
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/pseudo_mc/IC86-2011.npy
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/IC86-2012.npy
# Found: /Users/avocado/flarestack__data/input/public_datasets/all_sky_3_year/events/pseudo_mc/IC86-2012.npy
